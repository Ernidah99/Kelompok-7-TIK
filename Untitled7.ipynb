# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernidah99/Kelompok-7-TIK/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
("hello world")
# Out:
# 'hello world'
