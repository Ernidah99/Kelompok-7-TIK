# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernidah99/Kelompok-7-TIK/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sconds_in_a_day= 24 * 60 * 60
sconds_in_a_day
# Out:
# 86400
